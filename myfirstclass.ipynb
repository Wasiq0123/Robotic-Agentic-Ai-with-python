# %%
#-----This is my first programe -----/////

print ('Hello world')
print ('wasiq khan')
print ('Iam a student of Agentic and robotic Ai')
print ('My professor name is Sir  Rehan  and Sir usman .He is Very nice teacher')

#=======Print Name 10 time-============
print('wasiq khan')
print('wasiq khan')
print('wasiq khan')
print('wasiq khan')
print('wasiq khan')
print('wasiq khan')
print('wasiq khan')


#----This is my first variable where i store my name -------////
#====Benifits for Storing varible i cabn change i palce they all chages aplly------//
my_name='wasiq khan'
my_teacheranme='Sir Rehan'
print(my_name)
print(my_teacheranme)

#------Data type--------
#-------String =>str-------

my_name :str='Hareem Adan'

# we are suing string data type with my_name bcz large application is very complextsity to understand which type data type .Daveloper can easily to understand
print(my_name)

#=======Input() Funtion ========
#====In input() fuction value are always consider as string when we are not mention it ====

#std_name:str=input('Enter your name')
#print(std_name)

#=====Operator In Python==========
#===== Airthmatic Operator ==========

#-------Write the program adding two number
first_num:int=10
second_num:int=20

#------This is the example of '+' Operator
result=first_num+second_num
print(result)


#-------Write the program Subtract two number
first_num:int=50
second_num:int=10

#------This is the example of '-' Operator
result=first_num-second_num
print(result)

#-------Write the program Multiply two number
first_num:int=18
second_num:int=2

#------This is the example of '*' Operator
result=first_num*second_num
print(result)

#-------Write the program Divide two number
first_num:int=10
second_num:int=20

#------This is the example of '/' Operator
result=first_num/second_num
print(result)

#-------Write the program Power of two number
first_num:int=5
second_num:int=2

#------This is the example of '**' Operator
result=first_num**second_num
print(result)

#-------Write the program Modlus two number
print(10%2)


#-------List----------!
#------List are Srt zero they are Left to right and top to bottom------

name_list:list[str]=['wasiq','Ali','Hareem','Adan','Ali']

#-----Print the All list --------
print(name_list)

#-----------appened method is used for insert object in list they are showing in last o flist -------

name_list.append("Atif")
print(name_list)
#-------- .clear() method list sa sari entry remove kr da ga --------
#name_list.clear()
#print(name_list)


#---------.copy() method is used to copy of the list -------
name_list.copy()
print(name_list)

#---------.count() method is used to count the object  of the list -------
result=name_list.count('Ali')
print(result)

#---------.extend() method sa fatima String ki trah add ho gi har words STring ho ga  -------
name_list.extend('Fatima')
print(name_list)


#--------Used of etend() method hum list k andr list add kr sakta ha --------
#-----key point:jab hum kisi list ko kisi 2sri list k andr merge kr rha hot ha to jis list k andr copy krna ha 1 list.extends(newlist)

new_list:list[str]=['Sobia','waris khan']
name_list.extend(new_list)
print(name_list)


#------

result=name_list.index('Ali')
print(name_list)

#------print firts name---------
#print(name_list[0])

#print(name_list[3])


#-------List of Integer ----------!
num_list :list[int]=[0,12,45,65,23]

#------print All integer list -------
print(num_list)
#-------print the second no. of list
print(num_list[2])

#-----List of  integer/float and string-------
mix_list:list[str|int|float]=['wasiq Khan',3.14,'Ali',45]
print(mix_list[2])
# Out:
# Hello world
# wasiq khan
# Iam a student of Agentic and robotic Ai
# My professor name is Sir  Rehan  and Sir usman .He is Very nice teacher
# wasiq khan
# wasiq khan
# wasiq khan
# wasiq khan
# wasiq khan
# wasiq khan
# wasiq khan
# wasiq khan
# Sir Rehan
# Hareem Adan
# 30
# 40
# 36
# 0.5
# 25
# 0
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali']
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali', 'Atif']
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali', 'Atif']
# 2
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali', 'Atif', 'F', 'a', 't', 'i', 'm', 'a']
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali', 'Atif', 'F', 'a', 't', 'i', 'm', 'a', 'Sobia', 'waris khan']
# ['wasiq', 'Ali', 'Hareem', 'Adan', 'Ali', 'Atif', 'F', 'a', 't', 'i', 'm', 'a', 'Sobia', 'waris khan']
# [0, 12, 45, 65, 23]
# 45
# Ali
